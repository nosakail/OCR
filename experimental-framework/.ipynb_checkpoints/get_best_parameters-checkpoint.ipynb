# %%
import imutils
import easyocr
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#have list of images path
from glob import glob 
data_dir = 'test'
img_fns = glob(data_dir + '/*')
#print(img_fns)

# %% [markdown]
# # Get fonction with easy_ocr best parameters

# %%
img = cv2.imread(data_dir + '/image001.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 649.5, 439.5, -0.5)

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
ok = cv2.cvtColor(edged, cv2.COLOR_BGR2RGB)
#plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))
plt.imshow(edged)

# %%
reader = easyocr.Reader(['en'], gpu = False)#create reader with english langage

result = reader.readtext(edged)
print(result)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[240, 121], [349, 121], [349, 165], [240, 165]], 'onALi', 0.44663568280819066)]
