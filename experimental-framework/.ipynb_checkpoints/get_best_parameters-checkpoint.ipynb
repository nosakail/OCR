# %%
import imutils
import easyocr
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#have list of images path
from glob import glob 
data_dir = 'test'
img_fns = glob(data_dir + '/*')
#print(img_fns)

# %% [markdown]
# # Get fonction with easy_ocr best parameters

# %%
img = cv2.imread(data_dir + '/image002.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 767.5, -0.5)

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
#edged = cv2.Canny(bfilter, 30, 200) #Edge detection
#ok = cv2.cvtColor(gray, cv2.COLOR_BGR2RGB)
#plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))
#plt.imshow(ok)

# %%
reader = easyocr.Reader(['en'], gpu = False)#create reader with english langage
result_1 = reader.readtext(bfilter, decoder='beamsearch') #img de base avec bfilter et beamsearch
result_2 = reader.readtext(bfilter, decoder='wordbeamsearch')# img de base avec bfilter et wordbeamsearch
result_3 = reader.readtext(img) # img de base
print(result_1)
print('----------------------------------------------------')
print('----------------------------------------------------')
print(result_2)
print('----------------------------------------------------')
print('----------------------------------------------------')
print(result_3)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[346, 330], [466, 330], [466, 486], [346, 486]], '4', 0.474296306225952), ([[153, 477], [662, 477], [662, 664], [153, 664]], 'BEACH', 0.4897234167997189), ([[85.39527057362662, 223.16216458901297], [779.9495086618938, 169.4412574262267], [777.6047294263734, 344.837835410987], [83.05049133810624, 398.5587425737733]], 'SEACREST', 0.9789898332343427)]
# ----------------------------------------------------
# ----------------------------------------------------
# [([[346, 330], [466, 330], [466, 486], [346, 486]], '4', 0.474296306225952), ([[153, 477], [662, 477], [662, 664], [153, 664]], 'BEACH', 0.4897234167997189), ([[85.39527057362662, 223.16216458901297], [779.9495086618938, 169.4412574262267], [777.6047294263734, 344.837835410987], [83.05049133810624, 398.5587425737733]], 'SEACREST', 0.9789898332343427)]
# ----------------------------------------------------
# ----------------------------------------------------
# [([[69, 154], [799, 154], [799, 412], [69, 412]], 'SiAcREST', 0.11717273795243355), ([[337, 337], [497, 337], [497, 497], [337, 497]], 'K', 0.2683587735245432), ([[153, 477], [661, 477], [661, 664], [153, 664]], 'BEACH', 0.9243787459375343)]

# %% [markdown]
# # Determine background color

# %%
from colorthief import ColorThief


def is_background_darkened(img_path):
    ct = ColorThief(img_path)
    dominent_color = ct.get_color(quality=1)
    #print(dominent_color)
    #plt.imshow([dominent_color])
    #plt.show()

    # Convertir la couleur en niveaux de gris
    gray = np.dot(dominent_color[0:3], [0.299, 0.587, 0.114])

    # Déterminer si la couleur du background est claire ou foncée
    if gray > 128:
        return False
    else:
        return True

#path = 'test/image001.jpg'
#result = is_background_darkened(path)
#print(result)

# %% [markdown]
# # IF BACKGROUND NOT DARKENED

# %%
def ajust_not_darkened_background(img):
    # Lire l'image
    #img = cv2.imread(img_path)
    
    # Convertir l'image en niveaux de gris
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Appliquer le seuillage
    _, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)
    
    # Inverser les couleurs
    inverted = cv2.bitwise_not(thresh)
    
    # Afficher l'image résultante
    #plt.imshow(inverted)
    return(inverted)

# %%
reader = easyocr.Reader(['en'], gpu = False)#create reader with english langage
result_1 = reader.readtext(inverted, decoder='beamsearch') #img de base avec bfilter et beamsearch
result_2 = reader.readtext(bfilter, decoder='wordbeamsearch')# img de base avec bfilter et wordbeamsearch
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
print(result_1)
print(result_2)
# Out:
# [([[153, 485], [663, 485], [663, 656], [153, 656]], 'BEACH', 0.9662760083506136), ([[82.1877241839707, 223.1891589613832], [764.8215060290512, 162.06401422000542], [764.8122758160293, 338.8108410386168], [82.17849397094881, 400.9359857799946]], 'SEACREST', 0.8574665000589388)]
# [([[346, 330], [466, 330], [466, 486], [346, 486]], '4', 0.474296306225952), ([[153, 477], [662, 477], [662, 664], [153, 664]], 'BEACH', 0.4897234167997189), ([[85.39527057362662, 223.16216458901297], [779.9495086618938, 169.4412574262267], [777.6047294263734, 344.837835410987], [83.05049133810624, 398.5587425737733]], 'SEACREST', 0.9789898332343427)]

# %% [markdown]
# # IF BACKGROUND DARKENED

# %%
def process_background_darkened(img_path):
    # Charger l'image
    img = cv2.imread(img_path)
        
    # Convertir l'image en niveaux de gris
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
    # Appliquer le seuillage inversé
    _, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV)
        
    # Inverser les couleurs
    invertedd = cv2.bitwise_not(thresh)
        
    # Afficher l'image originale et l'image inversée
    #cv2.imshow('Original Image', img)
    #plt.imshow(invertedd)
    return invertedd

# %%
reader = easyocr.Reader(['en'], gpu = False)#create reader with english langage
result_1 = reader.readtext(invertedd, decoder='beamsearch') #img de base avec bfilter et beamsearch
result_2 = reader.readtext(invertedd, decoder='wordbeamsearch')# img de base avec bfilter et wordbeamsearch

print(result_1)
print('-----------------------------------------------------------------------')
print(result_2)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[224, 119], [365, 119], [365, 179], [224, 179]], '<ONALDO', 0.11039348333943613)]
# -----------------------------------------------------------------------
# [([[224, 119], [365, 119], [365, 179], [224, 179]], '<ONALDO', 0.11039348333943613)]

# %% [markdown]
# # Fonction to dertermine low contrast

# %%
def is_low_contrast(img_path):
    # load image as YUV (or YCbCR) and select Y (intensity)
    # or convert to grayscale, which should be the same.
    # Alternately, use L (luminance) from LAB.
    img = cv2.imread(img_path)
    Y = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)[:,:,0]
    
    # compute min and max of Y
    min = np.min(Y)
    max = np.max(Y)
    
    # compute contrast
    contrast = (max-min)/(max+min)
    if contrast < 0.5 :
        return True 
    else :
        return False

    #print(min,max,contrast)
    #plt.imshow(img)
        
#img_path = 'test/low2.png'
#print(is_low_contrast(img_path))
# Out:
# True
# C:\Users\yassi\AppData\Local\Temp\ipykernel_23560\2469312999.py:13: RuntimeWarning: overflow encountered in scalar add
#   contrast = (max-min)/(max+min)

# %% [markdown]
# # IF LOW CONTRAST

# %%
imgo = cv2.imread('test/low2.png')

# Charger l'image
img = cv2.imread('test/low2.png', cv2.IMREAD_GRAYSCALE)

# Appliquer l'égalisation d'histogramme
img_equalized = cv2.equalizeHist(img)

# Afficher les images d'origine et égalisée côte à côte
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(imgo)
axs[0].set_title('Original Image')
axs[1].imshow(img_equalized, cmap='gray')
axs[1].set_title('Equalized Image')
plt.show()

# %% [markdown]
# # IF saturation

# %%
import os


data_dir = 'data'
image_exts = ['jpeg', 'jpg', 'bmp', 'png']

for image in os.listdir(data_dir):
    if image.lower().split('.')[-1] in image_exts:
        image_path = os.path.join(data_dir, image)
        
        try:
            img = cv2.imread(image_path)
            
            if img is not None:
                img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
                saturation = img_hsv[:, :, 1].mean()
                print(f"Saturation for {image}: {saturation}")
            else:
                print(f"Failed to read {image_path}")
        except Exception as e:
            print(f"Error processing {image}: {e}")
# Out:
# Saturation for image000.png: 11.517567049808429
# Saturation for image001.jpg: 89.40547202797202
# Saturation for image002.jpg: 37.425462086995445
# Saturation for image003.jpg: 80.95565923055013
# Saturation for image004.jpg: 24.26304503435864
# Saturation for image005.jpg: 88.16714159647624
# Saturation for image006.jpg: 71.57934798715237
# Saturation for image007.jpg: 97.71315703309351
# Saturation for image008.jpg: 103.6965445807771
# Saturation for image009.jpg: 109.80451336772983
# Saturation for image010.jpg: 132.70598602294922
# Saturation for image011.jpg: 175.78981267539044
# Saturation for image012.jpg: 32.92451763429192
# Saturation for image013.jpg: 123.42931199980674
# Saturation for image014.jpg: 190.7887173502704
# Saturation for image015.jpg: 91.5081591371114
# Saturation for image016.jpg: 103.51986694335938
# Saturation for image017.jpg: 117.29848988850911
# Saturation for image018.jpg: 162.84794014814815
# Saturation for image019.jpg: 86.66873705788049
# Saturation for image020.jpg: 115.93916617499457
# Saturation for image021.jpg: 74.34270788768548
# Saturation for image022.jpg: 71.4432638888889
# Saturation for image023.jpg: 85.44080307363434
# Saturation for image024.jpg: 82.05359113563546
# Saturation for image025.jpg: 135.2507422225614
# Saturation for image026.jpg: 91.53173945734079
# Saturation for image027.jpg: 96.65736236572266
# Saturation for image028.jpg: 126.7274821566358
# Saturation for image029.jpg: 83.2823922829582
# Saturation for image030.jpg: 61.977375520833334
# Saturation for image031.jpg: 119.99715677897136
# Saturation for image032.jpg: 89.99246119733925
# Saturation for image033.jpg: 147.1870519203414
# Saturation for image034.jpg: 222.52879253112033
# Saturation for image035.jpg: 95.46030076694139
# Saturation for image036.jpg: 132.38042395227527
# Saturation for image037.jpg: 162.64215605520926
# Saturation for image038.jpg: 95.3313169456067
# Saturation for image039.jpg: 113.2928072611491
# Saturation for image040.jpg: 33.212695723554944
# Saturation for image041.jpg: 92.39949795198544
# Saturation for image042.jpg: 111.5351821698495
# Saturation for image043.jpg: 19.413216908772785
# Saturation for image044.jpg: 101.4461234375
# Saturation for image045.jpg: 133.01974643874644
# Saturation for image046.jpg: 72.59342956542969
# Saturation for image047.jpg: 106.03080571771979
# Saturation for image048.jpg: 53.437459309895836
# Saturation for image049.jpg: 83.08408472222222
# Saturation for image050.jpg: 109.57277173913043
# Saturation for image051.jpg: 41.371443112691246
# Saturation for image052.jpg: 47.81931312061916
# Saturation for image053.jpg: 127.8049601081812
# Saturation for image054.jpg: 44.192928571428574
# Saturation for image055.jpg: 63.19733231707317
# Saturation for image056.JPG: 99.27958344172737
# Saturation for image057.jpg: 70.28637720352565
# Saturation for image058.jpg: 148.70312881469727
# Saturation for image059.JPG: 151.7781271757903
# Saturation for image060.jpg: 68.26829875196019
# Saturation for image061.jpg: 98.68290237768633
# Saturation for image062.jpg: 61.136340181327164
# Saturation for image063.jpg: 150.56369684573494
# Saturation for image064.jpg: 79.88045120239258
# Saturation for image065.jpg: 120.72072760264079
# Saturation for image066.jpg: 96.31190290734625
# Saturation for image067.jpg: 60.23205230059752
# Saturation for image068.jpg: 70.52034550576336
# Saturation for image069.jpg: 83.56455370370371
# Saturation for image070.jpg: 36.58869279220673
# Saturation for image071.jpg: 194.1610435185185
# Saturation for image072.jpg: 52.67247517903646
# Saturation for image073.jpg: 182.0622494425864
# Saturation for image074.jpg: 120.77877928870294
# Saturation for image075.jpg: 60.908299479166665
# Saturation for image076.jpg: 98.08204656032783
# Saturation for image077.jpg: 42.95222623345367
# Saturation for image078.JPG: 59.188373194317954
# Saturation for image079.jpg: 58.309197816432274
# Saturation for image080.jpg: 125.04336928571429

# %%
# Charger l'image
imageo = cv2.imread('data/image034.jpg')

# Convertir l'image en niveaux de gris
gray_image = cv2.cvtColor(imageo, cv2.COLOR_BGR2GRAY)

# Afficher l'image en niveaux de gris
plt.imshow(gray_image)

cv2.imwrite('img_to_process/gray_image.png', gray_image)
# Out:
# True

# %%
reader = easyocr.Reader(['en'], gpu = False)#create reader with english langage
result_1 = reader.readtext(gray_image, decoder='beamsearch') #img de base 
result_2 = reader.readtext(imageo, decoder='beamsearch')# img en appliquant un filtre

print(result_1)
print('-----------------------------------------------------------------------')
print(result_2)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[150, 97], [849, 97], [849, 394], [150, 394]], 'E34', 0.15355699163659503), ([[419, 282], [634, 282], [634, 466], [419, 466]], ')', 0.28017991649562646), ([[571, 665], [701, 665], [701, 757], [571, 757]], 'V', 0.3086855176693213), ([[316.20878658414273, 620.024099979941], [552.9772117108424, 706.2306000961951], [511.79121341585727, 809.975900020059], [274.0227882891576, 722.7693999038049]], 'YIL', 0.24670862017404038)]
# -----------------------------------------------------------------------
# [([[170, 107], [833, 107], [833, 366], [170, 366]], 'Aa', 0.1312248979864348), ([[323.2696491545933, 623.0222461353302], [547.9990930885779, 714.8524701669437], [505.7303508454067, 810.9777538646698], [280.0009069114221, 718.1475298330563]], 'VIL', 0.5219869338103615)]

# %%
img_path = 'img_to_process/gray_image.png'

result_img = process_background_darkened(img_path)

plt.imshow(result_img)

reader = easyocr.Reader(['en'], gpu = False)#create reader with english langage
result_1 = reader.readtext(result_img, decoder='beamsearch')  
print(result_1)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[370, 260], [690, 260], [690, 584], [370, 584]], '25', 0.23072350460766472), ([[192.39182312430967, 169.5672924972387], [683.8938085887314, 85.30521815297796], [698.6081768756903, 246.4327075027613], [207.10619141126858, 330.69478184702206]], 'AQEL', 0.022939616814255714)]
