# %%
import pandas as pd
import csv


import os
import csv
import cv2
import easyocr

# %%
with open('test.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        print(','.join(row))
# Out:
# name;words
# image001.jpg;RONALDO,7

# %%
'''
import os


data_dir = 't'

# Ouvrez le fichier CSV en mode écriture
with open('test.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=';')

    # Écrivez l'en-tête du fichier CSV
    writer.writerow(['name', 'words'])

    # Liste tous les fichiers dans le dossier data
    for filename in os.listdir(data_dir):
        # Vérifiez si le fichier est une image
        if filename.endswith(('.png', '.jpg', '.jpeg')):
            # Ajoutez le nom de fichier à la colonne "name"
            writer.writerow([filename, ''])
'''

# %%
#pour chaque image, pour chaque mot trouvé, on verifie si le mot et present dans la liste des mots de l'image, 
#si le mot est present dans la liste des mots de l'image, on le supprime de la liste des mots de l'image et
#on le deplace dans un liste safe_words_found.  
#Si un mots trouvé n'est pas present dans la liste des mots de l'image, on le met dans une liste words_found
#a la fin : nombre de mot dans liste mot_trouvé = nb_mot_trouve
#nombre mot dansliste mots_image = nb_mot_non_trouve.

# %%
data_dir = 'data'
safe_words_found = []
img_words = []
words_found = []

reader = easyocr.Reader(['en', 'ja'], gpu=False)

# Créer une liste de dictionnaires pour stocker les résultats
results = []

safe_words_total_number = 0
safe_words_found_total_number = 0

# Lire le fichier CSV
with open('data.csv', newline='') as csvfile:
    spamreader = csv.DictReader(csvfile, delimiter=';')
    for row in spamreader:
        img_words = row['words'].split(',')
        
        safe_words_total_number = safe_words_total_number + len(img_words)
        
        safe_words_found = []
        words_found = []
        # Lire l'image
        image_path = os.path.join(data_dir, row['name'])
        img = cv2.imread(image_path)
        # Utiliser EasyOCR pour trouver les mots dans l'image
        #reader = easyocr.Reader(['en', 'ja'], gpu=False)
        result = reader.readtext(img)
        # Vérifier si les mots trouvés sont dans la liste des mots de l'image
        for word in result:
            if word[1] in img_words:
                safe_words_found.append(word[1])
                img_words.remove(word[1])
            else:
                words_found.append(word[1])

        safe_words_found_total_number = safe_words_found_total_number + len(safe_words_found)
        
        
        # Stocker les résultats dans la liste de dictionnaires
        results.append({
            'name': row['name'],
            'safe_words_found': safe_words_found,
            'img_words': img_words,
            'words_found': words_found
        })

# Afficher les résultats
for result in results:
    nb_safe_words_found = len(result['safe_words_found'])
    nb_words_not_found = len(result['img_words'])
    if nb_words_not_found == 0 and len(result['words_found']) == 0:
        print(f"Image {result['name']} : perfect")
    else:
        print(f"Image {result['name']} : {nb_safe_words_found} safe words found, {nb_words_not_found} words not found, {len(result['words_found'])} words found in add")

print(str((safe_words_found_total_number * 100 / safe_words_total_number)) + "% of safe words found")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Image image000.png : 3 safe words found, 5 words not found, 5 words found in add
# Image image001.jpg : 0 safe words found, 2 words not found, 1 words found in add
# Image image002.jpg : 0 safe words found, 2 words not found, 3 words found in add
# Image image003.jpg : 0 safe words found, 2 words not found, 2 words found in add
# Image image004.jpg : 0 safe words found, 2 words not found, 6 words found in add
# Image image005.jpg : 0 safe words found, 4 words not found, 12 words found in add
# Image image006.jpg : 1 safe words found, 2 words not found, 5 words found in add
# Image image007.jpg : 4 safe words found, 3 words not found, 5 words found in add
# Image image008.jpg : 0 safe words found, 6 words not found, 4 words found in add
# Image image009.jpg : 0 safe words found, 4 words not found, 4 words found in add
# Image image010.jpg : 2 safe words found, 3 words not found, 0 words found in add
# Image image011.jpg : 0 safe words found, 1 words not found, 3 words found in add
# Image image012.jpg : 1 safe words found, 3 words not found, 4 words found in add
# Image image013.jpg : 0 safe words found, 3 words not found, 3 words found in add
# Image image014.jpg : 0 safe words found, 3 words not found, 2 words found in add
# Image image015.jpg : 1 safe words found, 1 words not found, 0 words found in add
# Image image016.jpg : 0 safe words found, 2 words not found, 7 words found in add
# Image image017.jpg : 1 safe words found, 1 words not found, 1 words found in add
# Image image018.jpg : 1 safe words found, 4 words not found, 4 words found in add
# Image image019.jpg : 0 safe words found, 2 words not found, 2 words found in add
# Image image020.jpg : 0 safe words found, 2 words not found, 2 words found in add
# Image image021.jpg : 1 safe words found, 3 words not found, 4 words found in add
# Image image022.jpg : 0 safe words found, 3 words not found, 5 words found in add
# Image image023.jpg : 2 safe words found, 7 words not found, 4 words found in add
# Image image024.jpg : 1 safe words found, 1 words not found, 1 words found in add
# Image image025.jpg : 1 safe words found, 1 words not found, 2 words found in add
# Image image026.jpg : 1 safe words found, 1 words not found, 0 words found in add
# Image image027.jpg : 0 safe words found, 2 words not found, 3 words found in add
# Image image028.jpg : 1 safe words found, 3 words not found, 5 words found in add
# Image image029.jpg : 0 safe words found, 3 words not found, 2 words found in add
# Image image030.jpg : 0 safe words found, 18 words not found, 12 words found in add
# Image image031.jpg : 0 safe words found, 1 words not found, 2 words found in add
# Image image032.jpg : 0 safe words found, 2 words not found, 4 words found in add
# Image image033.jpg : 0 safe words found, 2 words not found, 3 words found in add
# Image image034.jpg : 0 safe words found, 3 words not found, 2 words found in add
# Image image035.jpg : 0 safe words found, 1 words not found, 2 words found in add
# Image image036.jpg : 1 safe words found, 4 words not found, 4 words found in add
# Image image037.jpg : 1 safe words found, 8 words not found, 6 words found in add
# Image image038.jpg : 0 safe words found, 8 words not found, 14 words found in add
# Image image039.jpg : 0 safe words found, 2 words not found, 2 words found in add
# Image image040.jpg : 0 safe words found, 2 words not found, 6 words found in add
# Image image041.jpg : 0 safe words found, 3 words not found, 1 words found in add
# Image image042.jpg : 0 safe words found, 3 words not found, 4 words found in add
# Image image043.jpg : 1 safe words found, 3 words not found, 8 words found in add
# Image image044.jpg : 0 safe words found, 3 words not found, 9 words found in add
# Image image045.jpg : 0 safe words found, 4 words not found, 4 words found in add
# Image image046.jpg : 0 safe words found, 1 words not found, 3 words found in add
# Image image047.jpg : 0 safe words found, 3 words not found, 3 words found in add
# Image image048.jpg : 3 safe words found, 6 words not found, 9 words found in add
# Image image049.jpg : 1 safe words found, 4 words not found, 6 words found in add
# Image image050.jpg : 0 safe words found, 1 words not found, 3 words found in add
# Image image051.jpg : 0 safe words found, 2 words not found, 5 words found in add
# Image image052.jpg : 0 safe words found, 7 words not found, 7 words found in add
# Image image053.jpg : 0 safe words found, 1 words not found, 3 words found in add
# Image image054.jpg : 2 safe words found, 1 words not found, 6 words found in add
# Image image055.jpg : 0 safe words found, 2 words not found, 3 words found in add
# Image image057.jpg : 0 safe words found, 2 words not found, 5 words found in add
# Image image058.jpg : 0 safe words found, 4 words not found, 4 words found in add
# Image image060.jpg : 1 safe words found, 3 words not found, 3 words found in add
# Image image061.jpg : 1 safe words found, 7 words not found, 7 words found in add
# Image image062.jpg : 1 safe words found, 1 words not found, 4 words found in add
# Image image063.jpg : 1 safe words found, 3 words not found, 4 words found in add
# Image image064.jpg : 2 safe words found, 4 words not found, 4 words found in add
# Image image065.jpg : 0 safe words found, 5 words not found, 6 words found in add
# Image image066.jpg : 0 safe words found, 6 words not found, 8 words found in add
# Image image067.jpg : 0 safe words found, 6 words not found, 10 words found in add
# Image image068.jpg : 1 safe words found, 7 words not found, 8 words found in add
# Image image069.jpg : 0 safe words found, 3 words not found, 4 words found in add
# Image image070.jpg : 0 safe words found, 3 words not found, 3 words found in add
# Image image071.jpg : 1 safe words found, 2 words not found, 7 words found in add
# Image image072.jpg : 1 safe words found, 0 words not found, 4 words found in add
# Image image073.jpg : 0 safe words found, 6 words not found, 10 words found in add
# Image image074.jpg : 0 safe words found, 7 words not found, 15 words found in add
# Image image075.jpg : 0 safe words found, 10 words not found, 11 words found in add
# Image image076.jpg : 0 safe words found, 12 words not found, 13 words found in add
# Image image077.jpg : 0 safe words found, 2 words not found, 3 words found in add
# Image image079.jpg : 0 safe words found, 2 words not found, 4 words found in add
# Image image080.jpg : 0 safe words found, 2 words not found, 4 words found in add
# 12.5% of safe words found

# %% [markdown]
# # Evaluation fonction

# %%
'''
for each image, for each word found, we check if the word is present in the list of words in the image,
if the word is present in the list of words in the image, we delete it from the list of words in the image and
we replace it in a safe_words_found list.
If a word found is not present in the list of words in the image, we put it in a listwords_found
at the end: number of words in word_found list = nb_word_found
number of words in word_image list = nb_word_not_found.

Fonction take str in paramaters and return nothing
'''

def evaluation(data_dir, csv_file):
    
    data_dir = data_dir
    safe_words_found = []
    img_words = []
    words_found = []

    reader = easyocr.Reader(['en', 'ja'], gpu=False)

    # Créer une liste de dictionnaires pour stocker les résultats
    results = []

    safe_words_total_number = 0
    safe_words_found_total_number = 0

    # Lire le fichier CSV
    with open(csv_file, newline='') as csvfile:
        spamreader = csv.DictReader(csvfile, delimiter=';')
        for row in spamreader:
            img_words = row['words'].split(',')
        
            safe_words_total_number = safe_words_total_number + len(img_words)
        
            safe_words_found = []
            words_found = []
            # Lire l'image
            image_path = os.path.join(data_dir, row['name'])
            img = cv2.imread(image_path)
            # Utiliser EasyOCR pour trouver les mots dans l'image
            #reader = easyocr.Reader(['en', 'ja'], gpu=False)
            result = reader.readtext(img)
            # Vérifier si les mots trouvés sont dans la liste des mots de l'image
            for word in result:
                if word[1] in img_words:
                    safe_words_found.append(word[1])
                    img_words.remove(word[1])
                else:
                    words_found.append(word[1])
            safe_words_found_total_number = safe_words_found_total_number + len(safe_words_found)
        
        
            # Stocker les résultats dans la liste de dictionnaires
            results.append({
                'name': row['name'],
                'safe_words_found': safe_words_found,
                'img_words': img_words,
                'words_found': words_found
            })

    # Afficher les résultats
    for result in results:
        nb_safe_words_found = len(result['safe_words_found'])
        nb_words_not_found = len(result['img_words'])
        if nb_words_not_found == 0 and len(result['words_found']) == 0:
            print(f"Image {result['name']} : perfect")
        else:
            print(f"Image {result['name']} : {nb_safe_words_found} safe words found, {nb_words_not_found} words not found, {len(result['words_found'])} words found in add")
    
    print(str((safe_words_found_total_number * 100 / safe_words_total_number)) + "% of safe words found")

# %%
data_dir = 't'
csv_file = 'test.csv'
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Image image001.jpg : 0 safe words found, 2 words not found, 1 words found in add
# 0.0% of safe words found
